# %% [markdown]
# <a href="https://colab.research.google.com/github/mohmmad25-hub/ANN/blob/main/matplotlib_and_seaborn_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Line Plot

# %%
x = [1,2,3,4,5]
y = [10, 15, 7, 12, 8]

# create a line plot
plt.plot(x,y, marker='o', color='red', linestyle = '--', linewidth = 2)

# add labels and titles
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Line Plot')
plt.grid(True)

# display the plot
plt.show()

# %%
import pandas as pd

# create a dataframe
data = {
    'Year': [2010, 2011,2012, 2013, 2014],
    'Sales': [500, 800, 1700, 1500, 2000]
}
df = pd.DataFrame(data)

# Create a line plot
plt.plot(df['Year'], df['Sales'], marker='o')
plt.xlabel('Year')
plt.ylabel('Sales')
plt.title('Sales over years')
plt.grid(True)

plt.xticks(df['Year'])

plt.show()

# %% [markdown]
# # **Bar blot**

# %%
data = {
    'Category': ['A', 'B', 'C', 'D'],
    'Values': [5, 8, 12, 15]
}

df_1 = pd.DataFrame(data)

plt.bar(df_1['Category'], df_1['Values'])
plt.xlabel('Category')
plt.ylabel('Values')
plt.title('Bar Plot')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    'Age': [25, 30, 22, 35, 28],
    'Income': [5000, 60000, 4500, 70000, 55000]
}

df_2 = pd.DataFrame(data)

plt.bar(df_2['Age'], df_2['Income'])
plt.xlabel('Age')
plt.ylabel('Income')
plt.title('Bar Plot')
plt.grid(True)
plt.show()

# %% [markdown]
# # Scatter Plot

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    'Age': [25, 30, 22, 35, 28],
    'Income': [5000, 60000, 4500, 70000, 55000]
}

df_2 = pd.DataFrame(data)

plt.scatter(df_2['Age'], df_2['Income'])
plt.xlabel('Age')
plt.ylabel('Income')
plt.title('Bar Plot')
plt.grid(True)
plt.show()

# %% [markdown]
# # Histogram Plot

# %%
# Creating a dataframe
import pandas as pd

data = {
    'Scores': [85, 78, 92, 65, 80, 75, 88, 90, 82, 70]
}

df_3 = pd.DataFrame(data)

# %%
# create a histogram of the data
plt.hist(df_3['Scores'], width = 1.5)
plt.xlabel('Scores')
plt.ylabel('Frequency')
plt.title('Distribution of scores')
plt.grid(True)
plt.show()

# %% [markdown]
# # Box Plot

# %%
# Sample data
data = [10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60, 65, 70]

plt.boxplot(data)
plt.show()

# %% [markdown]
# # Seaborn
#
# **Seaborn is an open-source Python data visualization library built on top of Matplotlib.**  It is specifically designed for creating attractive and informative statistical graphics. **Seaborn provides a higher-level interface compared to Matplotlib, making it easier to generate complex visualizations with fewer lines of code.** It is particularly useful for creating visually appealing visualizations for data exploration, analysis, and presentation.

# %%
import seaborn as sns

data = sns.load_dataset('iris')

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
data['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
sns.scatterplot(data = data, x = 'sepal_length', y = 'sepal_width', hue='species')
plt.title('Scattered plot using sns')
plt.show()

# %%
data = sns.load_dataset('tips')
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
day = data['day'].unique()
time = data['time'].unique()
print(day)
print(time)
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']
# ['Dinner', 'Lunch']
# Categories (2, object): ['Lunch', 'Dinner']

# %%
sns.barplot(data = data, x = 'day', y = 'total_bill', hue = 'sex')
plt.title('Bar plot using sns')
plt.show()

# %%
data.describe().T
# Out:
#             count       mean       std   min      25%     50%      75%    max
# total_bill  244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275  50.81
# tip         244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625  10.00
# size        244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000   6.00

# %%
data_1 = sns.load_dataset('fmri')
data_1.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.lineplot(data = data_1, x = 'timepoint', y = 'signal', hue = 'region')
plt.title('Line plot using sns')
plt.show()
